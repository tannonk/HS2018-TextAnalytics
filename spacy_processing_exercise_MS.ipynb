# %% [raw]
# ## Install necessary dependencies.
# ##
# ## scpacy (https://spacy.io/usage/#section-quickstart):
# ##     $ pip install -U spacy
# ## if you use conda:
# ##     $ conda install -c conda-forge spacy
# ## spacy's English language model:
# ##     $ python -m spacy download en
# ## gensim (https://radimrehurek.com/gensim/install.html):
# ##     $ pip install --upgrade gensim
# ## or, if you use conda:
# ##     $ conda install -c conda-forge gensim

# %%
import re
import spacy
from gensim import corpora # necessary for building dictionary and bag of words representation
from gensim import models # necessary for Phrases, LDA model and TFIDF

# %% [raw]
# ## If there's time, could also work out how to visualise the results with PyLDA

# %%
nlp = spacy.load("en")

# %%
corpus = "snf_html_corpus_simple.txt"

raw_corpus = []

with open(corpus, "r", encoding="utf8") as inf:    
    doc = ""
    for line in inf:
        if not line.startswith("\n"): # we are inside a document
            line = re.sub("\xa0", " ", line.rstrip())
            doc += line.lower() # lower and add the line to the document string
        else: # we are at a document boundary
            if len(doc) > 380: # ignore shorter documents
                raw_corpus.append(doc) # should end up with 110 articles in list of docs 
            doc = ""

# inspect the raw_corpus:
# raw_corpus

# %%
# testing on one doc:

# pro_doc = nlp(docs[0])
# print(pro_doc)

# Inspect entities found
# pro_doc.ents

# for token in pro_doc[:100]:
#     print(token.text, token.lemma_, token.pos_, token.tag_,
#           token.dep_, token.shape_, token.is_alpha, token.is_stop)

# %%
# add stopwords
noisy_words = ["research", "say", "says", "said", "in", "not", "this", "researcher"]

for w in noisy_words:
    nlp.vocab[w].is_stop = True

# %%
# test = nlp("The research says that this man is not a researcher, but he is.".lower())
# for w in test:
#     if not w.is_stop:
#         print(w)

# %%
corpus, article = [], []

for doc in raw_corpus:
    doc = nlp(doc)
    for w in doc:
        # if it's not a stop word or punctuation mark, add it to our article!
        if w.text != " " and not w.is_stop and not w.is_punct and not w.like_num:
            # we add the lematized version of the word
            lemma = w.lemma_.strip("’") # removes things like "science’"
            if lemma:
                article.append(lemma)
    corpus.append(article)
    article = []

# inspect corpus
corpus
# Out:
# [['observer',
#   'consider',
#   'overcome',
#   'issue',
#   'require',
#   'new',
#   'paradigm',
#   'open',
#   'science',
#   'idea',
#   'break',
#   'shackle',
#   'fetter',
#   'individual',
#   'element',
#   'scientific',
#   'production',
#   'process',
#   'formation',
#   'hypothesis',
#   'publication',
#   'result',
#   'infographic',
#   'element',
#   'open',
#   'science',
#   'p.',
#   'watchword',
#   'sharing',
#   'inclusion',
#   'collaboration',
#   'decentralisation',
#   'transparency',
#   'fully',
#   'open',
#   'work',
#   'useful',
#   'scientist',
#   'industry',
#   'member',
#   'civil',
#   'society',
#   'computer',
#   'program',
#   'able',
#   'draw',
#   'new',
#   'conclusion',
#   'old',
#   'result',
#   'pillar',
#   'open',
#   'access',
#   'aim',
#   'ensure',
#   'scientific',
#   'publication',
#   'accessible',
#   'free',
#   'charge',
#   'people',
#   'little',
#   'impatient',
#   'clearly',
#   'right',
#   'track',
#   'daniël',
#   'laken',
#   'psychology',
#   'practitioner',
#   'open',
#   'science',
#   'eindhoven',
#   'university',
#   'technology',
#   'accord',
#   'european',
#   'study',
#   'publish',
#   'half',
#   'article',
#   'publish',
#   'open',
#   'access',
#   'question',
#   'cost',
#   'remain',
#   'open',
#   'access',
#   'journal',
#   'consult',
#   'free',
#   'charge',
#   'average',
#   'cost',
#   'publish',
#   'article',
#   'eur',
#   'factor',
#   'prepublication',
#   'archive',
#   'arxiv',
#   'ssrn',
#   'offer',
#   'free',
#   'access',
#   'manuscript',
#   'submit',
#   'journal',
#   'tariff',
#   'publish',
#   'article',
#   'continually',
#   'increase',
#   'bone',
#   'contention',
#   'science',
#   'publishing',
#   'react',
#   'confront',
#   'piracy',
#   'website',
#   'million',
#   'article',
#   'available',
#   'illegally',
#   'second',
#   'pillar',
#   'open',
#   'datum',
#   'involve',
#   'radical',
#   'change',
#   'attitude',
#   'scientist',
#   'regard',
#   'raw',
#   'datum',
#   'consider',
#   'belong',
#   'laken',
#   'work',
#   'revolve',
#   'interpretation',
#   'result',
#   'formulation',
#   'clear',
#   'concise',
#   'conclusion',
#   'disclosure',
#   'primary',
#   'datum',
#   'approach',
#   'render',
#   'impossible',
#   'comparison',
#   'question',
#   'choice',
#   'interpretation',
#   'type',
#   'statistical',
#   'analysis',
#   'employ',
#   'publication',
#   'bias',
#   'general',
#   'practice',
#   'publish',
#   'positive',
#   'result',
#   'big',
#   'problem',
#   'today',
#   's',
#   'science',
#   'fix',
#   'require',
#   'access',
#   'datum',
#   'particularly',
#   'include',
#   'publication',
#   'laken',
#   'scientist',
#   'individual',
#   'direct',
#   'interest',
#   'share',
#   'raw',
#   'datum',
#   'particularly',
#   'light',
#   'burden',
#   'time',
#   'cost',
#   'case',
#   'development',
#   'computer',
#   'skill',
#   'open',
#   'datum',
#   'continue',
#   'rely',
#   'individual',
#   'initiative',
#   'proviso',
#   'certain',
#   'programme',
#   'need',
#   'new',
#   'incentive',
#   'open',
#   'datum',
#   'today',
#   'minimal',
#   'impact',
#   's',
#   'reputation',
#   'sascha',
#   'friesike',
#   'alexand',
#   'von',
#   'humboldt',
#   'institute',
#   'internet',
#   'society',
#   'hiig',
#   'berlin',
#   'doctoral',
#   'student',
#   'management',
#   'innovation',
#   'university',
#   'st',
#   'gallen',
#   'thing',
#   'change',
#   'particularly',
#   'number',
#   'public',
#   'private',
#   'financing',
#   'body',
#   'introduce',
#   'requirement',
#   'share',
#   'datum',
#   'stem',
#   'pay',
#   'add',
#   'datum',
#   'need',
#   'precise',
#   'disclosure',
#   'methodology',
#   'acquire',
#   'laboratory',
#   'method',
#   'adjustment',
#   'instrumentation',
#   'possible',
#   'group',
#   'reproduce',
#   'result',
#   'subsequently',
#   'validate',
#   'refute',
#   'open',
#   'science',
#   'movement',
#   'aspire',
#   'world',
#   'researcher',
#   'resolve',
#   'problem',
#   'concert',
#   'lab',
#   'notebook',
#   'available',
#   'everybody',
#   'internet',
#   'science',
#   'tackle',
#   'problem',
#   'increasingly',
#   'complex',
#   'need',
#   'great',
#   'collaboration',
#   'friesike',
#   'instead',
#   'meet',
#   'rigid',
#   'requirement',
#   'programme',
#   'researcher',
#   'interested',
#   'organise',
#   'launch',
#   'call',
#   'collaboration',
#   'open',
#   'pressure',
#   'share',
#   'datum',
#   'method',
#   'facility',
#   'hardly',
#   'incentive',
#   'join',
#   'project',
#   'b.',
#   'fecher',
#   's.',
#   'friesike',
#   'open',
#   'science',
#   'term',
#   'school',
#   'thought',
#   'ssrn'],
#  ['open',
#   'science',
#   'mean',
#   'school',
#   'computer',
#   'communication',
#   'science',
#   'epfl',
#   'traditionally',
#   'publish',
#   'paper',
#   'freely',
#   'available',
#   'online',
#   'provide',
#   'associated',
#   'datum',
#   'source',
#   'code',
#   'manner',
#   'result',
#   'reproduce',
#   'group',
#   'researcher',
#   'drown',
#   'paper',
#   'today',
#   'hope',
#   'go',
#   'freely',
#   'available',
#   'open',
#   'science',
#   'exact',
#   'opposite',
#   'happen',
#   'publish',
#   'article',
#   'basis',
#   'mean',
#   'data',
#   'document',
#   'clearly',
#   'step',
#   'work',
#   'lead',
#   'result',
#   'describe',
#   'comprehend',
#   'mean',
#   'overall',
#   'few',
#   'paper',
#   'publish',
#   'quality',
#   'rise',
#   'time',
#   'transparent',
#   'exactly',
#   'publish',
#   'traditional',
#   'journal',
#   'be',
#   'submit',
#   'paper',
#   'datum',
#   'server',
#   'soon',
#   'article',
#   'accept',
#   'place',
#   'free',
#   'online',
#   'access',
#   'not',
#   'right',
#   'laboratory',
#   'recipe',
#   'certainly',
#   'field',
#   'computer',
#   'science',
#   'maybe',
#   'apply',
#   'field',
#   'year',
#   'ago',
#   'move',
#   'age',
#   'alchemy',
#   'chemistry',
#   'alchemist',
#   'simply',
#   'claim',
#   'produce',
#   'gold',
#   'accord',
#   'secret',
#   'method',
#   'possibility',
#   'check',
#   'claim',
#   'systematically',
#   'choose',
#   'believe',
#   'change',
#   'onset',
#   'chemistry',
#   'begin',
#   'publish',
#   'method',
#   'moment',
#   'modern',
#   'science',
#   'bear',
#   'thing',
#   'differently',
#   'today',
#   'be',
#   'return',
#   'age',
#   'alchemy',
#   'publication',
#   'result',
#   'snsf',
#   'funding',
#   'percent',
#   'freely',
#   'available',
#   'president',
#   'council',
#   'ok',
#   'be',
#   'frustrated',
#   'slow',
#   'today',
#   'swiss',
#   'taxpayer',
#   'pay',
#   'time',
#   'actual',
#   'secondly',
#   'subscription',
#   'specialist',
#   'journal',
#   'be',
#   'publish',
#   'thirdly',
#   'open',
#   'access',
#   'mean',
#   'publisher',
#   'profit',
#   'twice',
#   'be',
#   'truly',
#   'shameful',
#   'not',
#   'tolerate',
#   'want',
#   'achieve',
#   'switzerland',
#   'centre',
#   'able',
#   'present',
#   'united',
#   'publisher',
#   'deal',
#   'swiss',
#   'community',
#   'boycott',
#   'difficult',
#   'course',
#   'netherland',
#   'manage',
#   'have',
#   'successful',
#   'switzerland',
#   'ready',
#   'step',
#   'situation',
#   'complicated',
#   'different',
#   'researcher',
#   'active',
#   'switzerland',
#   'different',
#   'interest',
#   'be',
#   'find',
#   'little',
#   'difficult',
#   'coordinate',
#   'interest',
#   'not',
#   'snsf',
#   'simply',
#   'compel',
#   'researcher',
#   'publish',
#   'datum',
#   'open',
#   'access',
#   'journal',
#   'be',
#   'simple',
#   'case',
#   'bad',
#   'career',
#   'researcher',
#   'endeavour',
#   'publish',
#   'journal',
#   'best',
#   'suit',
#   'result',
#   'be',
#   'goal',
#   'career',
#   'researcher',
#   'hinder',
#   'not',
#   'epfl',
#   'find',
#   'specialist',
#   'journal',
#   'specialist',
#   'journal',
#   'good',
#   'idea',
#   'be',
#   'happen',
#   'basis',
#   'come',
#   'community',
#   'community',
#   'decide',
#   'leave',
#   'traditional',
#   'path',
#   'happen',
#   'be',
#   'person',
#   'decide',
#   'process',
#   'require',
#   'cultural',
#   'shift',
#   'researcher',
#   'researcher',
#   'go',
#   'path',
#   'yes',
#   'researcher',
#   'famous',
#   'mathematician',
#   'timothy',
#   'gower',
#   'university',
#   'cambridge',
#   'found',
#   'journal',
#   'discrete',
#   'analysis',
#   'be',
#   'virtual',
#   'journal',
#   'editorial',
#   'board',
#   'concentrate',
#   'solely',
#   'peer',
#   'reviewing',
#   'paper',
#   'submit',
#   'manage',
#   'external',
#   'company',
#   'cost',
#   'franc',
#   'manuscript',
#   'be',
#   'time',
#   'cheap',
#   'publish',
#   'traditional',
#   'journal',
#   'article',
#   'nature',
#   'show',
#   'important',
#   'cancer',
#   'study',
#   'reproducible',
#   'possible',
#   'fair',
#   'admit',
#   'difficult',
#   'field',
#   'medicine',
#   'example',
#   'small',
#   'datum',
#   'be',
#   'deal',
#   'real',
#   'people',
#   'mean',
#   'problem',
#   'statistic',
#   'reproducibility',
#   'reproducibility',
#   'crisis',
#   'affect',
#   'area',
#   'biology',
#   'choose',
#   'volume',
#   'datum',
#   'freely',
#   'have',
#   'hear',
#   'know',
#   'professor',
#   'claim',
#   'group',
#   'not',
#   'reproduce',
#   'be',
#   'good',
#   'people',
#   'real',
#   'knack',
#   'work',
#   'organism',
#   'experiment',
#   'succeed',
#   'not',
#   'reproduce',
#   'think',
#   'be',
#   'weakness',
#   'goal',
#   'science',
#   'absolute',
#   'reproducibility',
#   'not',
#   'people',
#   'cheat',
#   'happen',
#   'be',
#   'certainly',
#   'norm',
#   'remember',
#   'researcher',
#   'competition',
#   'bit',
#   'competition',
#   'today',
#   'result',
#   'pressure',
#   'make',
#   'researcher',
#   'feel',
#   'compel',
#   'publish',
#   'work',
#   'be',
#   'inadequate',
#   'competition',
#   'bad',
#   'not',
#   'simply',
#   'science',
#   'keen',
#   'discover',
#   'be',
#   'progress',
#   'clever',
#   'good',
#   'be',
#   'parcel',
#   'compete',
#   'be',
#   'problem',
#   'today',
#   'be',
#   'particularly',
#   'difficult',
#   'young',
#   'people',
#   'real',
#   'researcher',
#   'year',
#   'ago',
#   'leisure',
#   'think',
#   'differently',
#   'world',
#   'generate',
#   'new',
#   'idea',
#   'today',
#   'business',
#   'general',
#   'public',
#   'politician',
#   'private',
#   'sector',
#   'think',
#   'pour',
#   'money',
#   'end',
#   'useful',
#   'result',
#   'end',
#   'shortly',
#   'course',
#   'be',
#   'like',
#   'need',
#   'time',
#   'space',
#   'people',
#   'go',
#   'able',
#   'think',
#   'creatively',
#   'researcher',
#   'good',
#   'epfl',
#   'not',
#   'swiss',
#   'matter',
#   'global',
#   'alarm',
#   'phenomenon',
#   'certain',
#   'asian',
#   'country',
#   'example',
#   'researcher',
#   'wage',
#   'depend',
#   'specialist',
#   'journal',
#   'publish',
#   'be',
#   'dubious',
#   'practice',
#   'encourage',
#   'dishonest',
#   'behaviour',
#   'impact',
#   'switzerland',
#   'centre',
#   'yes',
#   'young',
#   'researcher',
#   'feel',
#   'pressure',
#   'publish',
#   'will',
#   'turn',
#   'material',
#   'article',
#   'article',
#   'look',
#   'better',
#   'publication',
#   'list',
#   'request',
#   'peer',
#   'review',
#   'be',
#   'huge',
#   'increase',
#   'recent',
#   'year',
#   'system',
#   'swamp',
#   'quality',
#   'consideration',
#   'naturally',
#   'leave',
#   'open',
#   'science',
#   'improve',
#   'current',
#   'system',
#   'shift',
#   'open',
#   'science',
#   'will',
#   'produce',
#   'few',
#   'good',
#   'quality',
#   'paper',
#   'review',
#   'quicker',
#   'document',
#   'be',
#   'epfl',
#   'president',
#   'concrete',
#   'measure',
#   'plan',
#   'promote',
#   'open',
#   'science',
#   'field',
#   'take',
#   'major',
#   'step',
#   'open',
#   'science',
#   'want',
#   'promote',
#   'culture',
#   'field',
#   'encourage',
#   'join',
#   'be',
#   'provide',
#   'online',
#   'tool',
#   'allow',
#   'researcher',
#   'upload',
#   'datum',
#   'easily',
#   'let',
#   'party',
#   'check',
#   'tool',
#   'intend',
#   'promote',
#   'collaboration',
#   'different',
#   'field',
#   'environmental',
#   'science',
#   'example',
#   'people',
#   'not',
#   'necessarily',
#   'accustom',
#   'deal',
#   'large',
#   'volume',
#   'datum',
#   'mathematician',
#   'computer',
#   'scientist',
#   'help',
#   'convince',
#   'young',
#   'researcher',
#   'value',
#   'open',
#   'science',
#   'tell',
#   'important',
#   'thing',
#   'career',
#   'work',
#   'big',
#   'impact',
#   'place',
#   'datum',
#   'online',
#   'work',
#   'visible',
#   'people',
#   'trust',
#   'help',
#   'work',
#   'big',
#   'impact',
#   'not',
#   'compel',
#   'embrace',
#   'be',
#   'realise'],
#  ['theory',
#   'evolution',
#   'support',
#   'egoistic',
#   'behaviour',
#   'level',
#   'dna',
#   'reflect',
#   'concept',
#   'selfish',
#   'gene',
#   'astonish',
#   'organism',
#   'actually',
#   'cooperate',
#   'mutual',
#   'assistance',
#   'work',
#   'male',
#   'female',
#   'bird',
#   'invest',
#   'jointly',
#   'rear',
#   'young',
#   'example',
#   'insect',
#   'create',
#   'veritable',
#   'states',
#   'task',
#   'share',
#   'emergence',
#   'cooperative',
#   'behaviour',
#   'perennial',
#   'topic',
#   'debate',
#   'biologist',
#   'subject',
#   'intensive',
#   'evolutionary',
#   'biologist',
#   'geneticist',
#   'game',
#   'theorist',
#   'take',
#   'dilemma',
#   'starting',
#   'point',
#   'wub',
#   'investigate',
#   'virtual',
#   'population',
#   'strategy',
#   'promote',
#   'cooperation',
#   'win',
#   'individual',
#   'punish',
#   'traitor',
#   'leave',
#   'pay',
#   'sense',
#   'eye',
#   'eye',
#   'different',
#   'parameter',
#   'mathematical',
#   'model',
#   'varied',
#   'different',
#   'round',
#   'interaction',
#   'size',
#   'population',
#   'actual',
#   'number',
#   'interaction',
#   'model',
#   'represent',
#   'simplification',
#   'real',
#   'circumstance',
#   'depict',
#   'biological',
#   'principle',
#   'realistically',
#   'large',
#   'group',
#   'advantageous',
#   'simply',
#   'avoid',
#   'disloyal',
#   'member',
#   'strategy',
#   'change',
#   'partner',
#   'dominant',
#   'big',
#   'group',
#   'big',
#   'number',
#   'interaction',
#   'wub',
#   'result',
#   'intuitively',
#   'comprehensible',
#   'large',
#   'group',
#   'individual',
#   'leave',
#   'non',
#   'cooperate',
#   'partner',
#   'good',
#   'chance',
#   'find',
#   'good',
#   'partner',
#   'punishment',
#   'alternative',
#   'require',
#   'lifelong',
#   'effort',
#   's',
#   'partner',
#   'place',
#   'strategy',
#   'change',
#   'population',
#   'size',
#   'number',
#   'interaction',
#   'small',
#   'group',
#   'good',
#   'punish',
#   'uncooperative',
#   'member',
#   'wub',
#   'case',
#   'bird',
#   'mean',
#   'renegade',
#   'partner',
#   'feather',
#   'tear',
#   'individual',
#   'carry',
#   'punishment',
#   'compel',
#   'partner',
#   'cooperate',
#   'small',
#   'group',
#   'advantageous',
#   'number',
#   'possible',
#   'cooperate',
#   'individual',
#   'small',
#   'surprisingly',
#   'computer',
#   'simulation',
#   'show',
#   'punishment',
#   'mean',
#   'choice',
#   'mid',
#   'size',
#   'population',
#   'interact',
#   'individual',
#   'not',
#   'result',
#   'wub',
#   'expect',
#   'simon',
#   'power',
#   'theoretical',
#   'biologist',
#   'modeller',
#   'lecture',
#   'napi',
#   'university',
#   'edinburgh',
#   'find',
#   'result',
#   'particularly',
#   'worthy',
#   'emphasis',
#   'biologist',
#   'long',
#   'debate',
#   'natural',
#   'selection',
#   'favour',
#   'punishment',
#   'non',
#   'cooperate',
#   'individual',
#   'power',
#   's',
#   'opinion',
#   'computer',
#   'model',
#   'develop',
#   'wub',
#   'colleague',
#   'show',
#   'punishment',
#   'outweigh',
#   'form',
#   'partner',
#   'control',
#   'elegant',
#   'math',
#   'clearly',
#   'help',
#   'acquire',
#   'new',
#   'insight',
#   'evolution',
#   'obvious',
#   'wub',
#   'theoretical',
#   'biologist',
#   'appeal',
#   'specialist',
#   'field',
#   'lie',
#   'precisely',
#   'form',
#   'knowledge',
#   'production',
#   'develop',
#   'hypothesis',
#   'test',
#   'empiricist',
#   'look',
#   'real',
#   'population',
#   'model',
#   'predict',
#   'exist',
#   'm.',
#   'wub',
#   'et',
#   'al',
#   'coevolution',
#   'positive',
#   'reciprocity',
#   'punishment',
#   'partner',
#   'switching',
#   'repeat',
#   'interaction',
#   'proceeding',
#   'royal',
#   'society',
#   'london',
#   'b'],
#  ['like',
#   'political',
#   'limelight',
#   'be',
#   'aware',
#   'research',
#   'topic',
#   'controversial',
#   'long',
#   'people',
#   'wait',
#   'apply',
#   'swiss',
#   'citizenship',
#   'policy',
#   'matter',
#   'astonishingly',
#   'free',
#   'controversy',
#   'positive',
#   'consequence',
#   'short',
#   'asylum',
#   'procedure',
#   'democracy',
#   'important',
#   'able',
#   'demonstrate',
#   'pro',
#   'con',
#   'different',
#   'policy',
#   'political',
#   'independence',
#   'field',
#   'emotionally',
#   'charge',
#   'aim',
#   'provide',
#   'cool',
#   'head',
#   'analysis',
#   'objective',
#   'instrument',
#   'people',
#   'form',
#   'fact',
#   'base',
#   'opinion',
#   'visibility',
#   'migration',
#   'topic',
#   'country',
#   'mean',
#   'increase',
#   'interest',
#   'work',
#   'recent',
#   'year',
#   'cope',
#   'politician',
#   'appropriate',
#   'result',
#   'task',
#   'accurate',
#   'analysis',
#   'identify',
#   'cause',
#   'effect',
#   'example',
#   'shorten',
#   'asylum',
#   'procedure',
#   'month',
#   'mean',
#   'refugee',
#   'begin',
#   'work',
#   'sooner',
#   'cost',
#   'state',
#   'promote',
#   'integration',
#   'secondly',
#   'ensure',
#   'result',
#   'understand',
#   'expert',
#   'laypeople',
#   'way',
#   'quantify',
#   'fund',
#   'people',
#   's',
#   'tax',
#   'better',
#   'succeed',
#   'room',
#   'misinterpretation',
#   'suggestion',
#   'good',
#   'integration',
#   'policy',
#   'politician',
#   'administrator',
#   'voter',
#   'decide',
#   'suggestion',
#   'practice',
#   'consider',
#   'withholding',
#   'result',
#   'fear',
#   'will',
#   'misunderstood',
#   'taboo',
#   'topic',
#   'researcher',
#   'rarely',
#   'good',
#   'time',
#   'publish',
#   'inconvenient',
#   'finding',
#   'speak',
#   'kind',
#   'situation',
#   'think',
#   'pretty',
#   'thick',
#   'skin',
#   'work',
#   'prompt',
#   'kind',
#   'reaction',
#   'read',
#   'commentary',
#   'social',
#   'medium',
#   'necessarily',
#   'meaningful',
#   'way',
#   'spend',
#   'time',
#   'stand',
#   'political',
#   'spectrum',
#   'interest',
#   'migration',
#   'topic',
#   'partly',
#   'biography',
#   'impact',
#   'scientific',
#   'process',
#   'conduct',
#   'result',
#   'want',
#   'understand',
#   'work',
#   'not',
#   'analysis',
#   'neutral',
#   'process',
#   'incentive',
#   'gloss',
#   'society',
#   'political',
#   'instrument',
#   'expensive',
#   'meaning',
#   'actually',
#   'achieve',
#   'case',
#   'country',
#   'review',
#   'intervene',
#   'public',
#   'debate',
#   'take',
#   'place',
#   'midst',
#   'society',
#   'communicate',
#   'result',
#   'affect',
#   'case',
#   'mean',
#   'involve',
#   'field',
#   'migration',
#   'choose',
#   'communication',
#   'partner',
#   'systematically',
#   'present',
#   'result',
#   'labour',
#   'market',
#   'integration',
#   'european',
#   'parliament',
#   'show',
#   'representative',
#   'different',
#   'country',
#   'datum',
#   'available',
#   'study',
#   'project',
#   'international',
#   'focus',
#   'be',
#   'swiss',
#   'help',
#   'remain',
#   'independent',
#   'help',
#   'relevant',
#   'switzerland',
#   'meet',
#   'interest',
#   'abroad',
#   'lot',
#   'european',
#   'country',
#   'interested',
#   'result',
#   'accelerate',
#   'asylum',
#   'process',
#   'example',
#   'ask',
#   'adapt',
#   'finnish',
#   'context',
#   'public',
#   'relation',
#   'work',
#   'mean',
#   'request',
#   'country',
#   'outside',
#   'switzerland',
#   'help',
#   'build',
#   'pressure',
#   'researcher',
#   'access',
#   'datum',
#   'country',
#   'previously',
#   'keep',
#   'wrap'],
#  ['trace',
#   'element',
#   'selenium',
#   'se',
#   'occur',
#   'tiny',
#   'concentration',
#   'essential',
#   'live',
#   'being',
#   'usually',
#   'get',
#   'attention',
#   'big',
#   'brother',
#   'iron',
#   'iodine',
#   'zinc',
#   'human',
#   'being',
#   'animal',
#   'reason',
#   'biogeochemist',
#   'lenny',
#   'winkel',
#   'department',
#   'environmental',
#   'science',
#   'eth',
#   'zurich',
#   'eawag',
#   'devote',
#   'intensively',
#   'trace',
#   'element',
#   'winkel',
#   'not',
#   'look',
#   'molecular',
#   'level',
#   'big',
#   'picture',
#   'team',
#   'investigate',
#   'distribution',
#   'selenium',
#   'look',
#   'like',
#   'globe',
#   'factor',
#   'determine',
#   'occur',
#   'basically',
#   'not',
#   'know',
#   'distribution',
#   'trace',
#   'element',
#   'winkel',
#   'concentration',
#   'selenium',
#   'soil',
#   'different',
#   'region',
#   'human',
#   'absorb',
#   'selenium',
#   'primarily',
#   'plant',
#   'base',
#   'foodstuff',
#   'plant',
#   'selenium',
#   'content',
#   'vary',
#   'greatly',
#   'accord',
#   'grow',
#   'estimate',
#   'half',
#   'people',
#   'world',
#   'suffer',
#   'selenium',
#   'deficiency',
#   'europe',
#   'switzerland',
#   'problem',
#   'concentration',
#   'selenium',
#   'soil',
#   'absorb',
#   'plant',
#   'winkel',
#   'mean',
#   'switzerland',
#   'necessarily',
#   'suffer',
#   'selenium',
#   'deficiency',
#   'rarely',
#   'subsist',
#   'purely',
#   'local',
#   'product',
#   'concentration',
#   'selenium',
#   'earth',
#   'decrease',
#   'account',
#   'global',
#   'warming',
#   'winkel',
#   'team',
#   'recently',
#   'publish',
#   'global',
#   'map',
#   'selenium',
#   'distribution',
#   'soil',
#   'europe',
#   'affected',
#   'area',
#   'continent',
#   'mongolia',
#   'authority',
#   'begin',
#   'programme',
#   'chicken',
#   'feed',
#   'enrich',
#   'selenium',
#   'egg',
#   'produce',
#   'chicken',
#   'help',
#   'reduce',
#   'deficiency',
#   'symptom',
#   'population',
#   'different',
#   'climate',
#   'soil',
#   'parameter',
#   'determine',
#   'selenium',
#   'concentrate',
#   'soil',
#   'rule',
#   'thumb',
#   'soil',
#   'dry',
#   'selenium',
#   'content',
#   'usually',
#   'low',
#   'rainfall',
#   'determine',
#   'concentration',
#   'condition',
#   'soil',
#   'play',
#   'important',
#   'role',
#   'organic',
#   'carbon',
#   'organic',
#   'material',
#   'bind',
#   'selenium',
#   'keep',
#   'longer',
#   'soil',
#   'lenny',
#   'winkel',
#   's',
#   'project',
#   'important',
#   'unique',
#   'markus',
#   'lenz',
#   'fhnw',
#   'school',
#   'life',
#   'science',
#   'research',
#   'selenium',
#   'comparable',
#   'project',
#   'deal',
#   'global',
#   'distribution',
#   'trace',
#   'element',
#   'selenium',
#   'easy',
#   'investigate',
#   'highly',
#   'complex',
#   'chemistry',
#   'occur',
#   'environment',
#   'different',
#   'bond',
#   'form',
#   'unclear',
#   'extent',
#   'phytoplankton',
#   'ocean',
#   'play',
#   'role',
#   'global',
#   'distribution',
#   'trace',
#   'element',
#   'winkel',
#   's',
#   'team',
#   'want',
#   'investigate',
#   'know',
#   'global',
#   'distribution',
#   'channel',
#   'selenium',
#   'hope',
#   'measure',
#   'combat',
#   'deficiency',
#   'specific',
#   'area',
#   'deficiency',
#   'climate',
#   'change',
#   'make',
#   'bad',
#   'lexandra',
#   'bröhm',
#   'science',
#   'journalist',
#   'tage',
#   'anzeiger',
#   'sonntagszeitung',
#   'g.d',
#   'jone',
#   'et',
#   'al',
#   'selenium',
#   'deficiency',
#   'risk',
#   'predict',
#   'increase',
#   'future',
#   'climate',
#   'change',
#   'pna'],
#  ['sign',
#   'language',
#   'natural',
#   'language',
#   'develop',
#   'linguistic',
#   'community',
#   'like',
#   'spoken',
#   'language',
#   'switzerland',
#   'use',
#   'swiss',
#   'german',
#   'french',
#   'italian',
#   'sign',
#   'language',
#   'modern',
#   'linguistic',
#   'sign',
#   'language',
#   'begin',
#   '1960',
#   'study',
#   'usa',
#   'netherland',
#   'switzerland',
#   'penny',
#   'boye',
#   'braem',
#   'found',
#   'center',
#   'sign',
#   'language',
#   'basel',
#   'private',
#   'non',
#   'profit',
#   'organisation',
#   'institution',
#   'switzerland',
#   'prepare',
#   'promote',
#   'language',
#   'look',
#   'explain',
#   'linguist',
#   'description',
#   'language',
#   'produce',
#   'perceive',
#   'visually',
#   'highly',
#   'interesting',
#   'shed',
#   'new',
#   'light',
#   'traditional',
#   'language',
#   'theory',
#   'example',
#   'sign',
#   'language',
#   'visual',
#   'iconicity',
#   'present',
#   'level',
#   'word',
#   'visible',
#   'relationship',
#   'linguistic',
#   'expression',
#   'cast',
#   'long',
#   'shadow',
#   'linguistic',
#   'principle',
#   'relationship',
#   'linguistic',
#   'sign',
#   'i.e.',
#   'word',
#   'meaning',
#   'arbitrary',
#   'human',
#   'language',
#   'example',
#   'word',
#   'concept',
#   'tree',
#   'different',
#   'unrelated',
#   'language',
#   'sign',
#   'language',
#   'world',
#   'sign',
#   'tree',
#   'offer',
#   'pictorial',
#   'aspect',
#   'form',
#   'tree',
#   'today',
#   'sign',
#   'language',
#   'investigate',
#   'institution',
#   'switzerland',
#   'university',
#   'applied',
#   'science',
#   'special',
#   'need',
#   'education',
#   'hfh',
#   'university',
#   'zurich',
#   'zurich',
#   'university',
#   'applied',
#   'science',
#   'winterthur',
#   'zhaw',
#   'project',
#   'need',
#   'researcher',
#   'master',
#   'sign',
#   'language',
#   'katja',
#   'tissi',
#   'hfh',
#   'deaf',
#   'birth',
#   'learn',
#   'sign',
#   'language',
#   'old',
#   'sister',
#   'deaf',
#   'child',
#   'feel',
#   'bad',
#   'sign',
#   'language',
#   'recall',
#   'swiss',
#   'expert',
#   'concentrate',
#   'send',
#   'hearing',
#   'impair',
#   'hear',
#   'speech',
#   'training',
#   'session',
#   'communicate',
#   'lip',
#   'reading',
#   'visit',
#   'usa',
#   'tissi',
#   'discover',
#   'sign',
#   'language',
#   'subject',
#   'scientific',
#   'see',
#   'sign',
#   'language',
#   'recognise',
#   'open',
#   'new',
#   'world',
#   'give',
#   'self',
#   'confidence',
#   'sign',
#   'language',
#   'profit',
#   'development',
#   'computer',
#   'multimedia',
#   'central',
#   'importance',
#   'image',
#   'recognition',
#   'like',
#   'people',
#   'hear',
#   'hearing',
#   'impair',
#   'people',
#   'internet',
#   'social',
#   'medium',
#   'explain',
#   'penny',
#   'boye',
#   'braem',
#   'order',
#   'communicate',
#   'internet',
#   'hearing',
#   'impair',
#   'produce',
#   'video',
#   'clip',
#   'sign',
#   'language',
#   'way',
#   'easily',
#   'identify',
#   'unlike',
#   'user',
#   'spoken',
#   'language',
#   'remain',
#   'anonymous',
#   'thank',
#   'use',
#   'write',
#   'communication',
#   'researcher',
#   'develop',
#   'technology',
#   'recognise',
#   'sign',
#   'video',
#   'translate',
#   'gesture',
#   'completely',
#   'anonymous',
#   'avatar',
#   'initial',
#   'step',
#   'direction',
#   'smile',
#   'project',
#   'scalable',
#   'multimodal',
#   'sign',
#   'language',
#   'technology',
#   'sign',
#   'language',
#   'learning',
#   'assessment',
#   'run',
#   'idiap',
#   'institute',
#   'martigny',
#   'collaboration',
#   'hfh',
#   'university',
#   'surrey',
#   'uk',
#   'project',
#   'develop',
#   'automatic',
#   'sign',
#   'language',
#   'recognition',
#   'technology',
#   'offer',
#   'learner',
#   'feedback',
#   'use',
#   'swiss',
#   'german',
#   'sign',
#   'language',
#   'automatic',
#   'machine',
#   'translation',
#   'play',
#   'role',
#   'doctoral',
#   'sarah',
#   'ebl',
#   'university',
#   'zurich',
#   'hear',
#   'impair',
#   'people',
#   'understand',
#   'platform',
#   'announcement',
#   'give',
#   'train',
#   'station',
#   'ebling',
#   'develop',
#   'system',
#   'enable',
#   'announcement',
#   'show',
#   'avatar',
#   'swiss',
#   'german',
#   'sign',
#   'language',
#   'dsgs',
#   'smartphone',
#   'area',
#   'include',
#   'signal',
#   'hand',
#   'face',
#   'cognitive',
#   'process',
#   'involve',
#   'sign',
#   'language',
#   'study',
#   'show',
#   'coordinate',
#   'manual',
#   'gesture',
#   'non',
#   'manual',
#   'component',
#   'great',
#   'challenge',
#   'adult',
#   'learner',
#   'hear',
#   'know',
#   'far',
#   'little',
#   'functioning',
#   'modality',
#   'specific',
#   'language',
#   'acquisition',
#   'explain',
#   'tobias',
#   'haug',
#   'director',
#   'study',
#   'hfh',
#   'order',
#   'investigate',
#   'hfh',
#   'plan',
#   'project',
#   'call',
#   'learner',
#   'corpus',
#   'dsgs',
#   'goal',
#   'learner',
#   'corpus',
#   'collect',
#   'datum',
#   'learner',
#   'certain',
#   'period',
#   'dsgs',
#   'acquisition',
#   'want',
#   'find',
#   'example',
#   'typical',
#   'difficulty',
#   'encounter',
#   'learn',
#   'sign',
#   'language'],
#  ['arrive',
#   'xàbia',
#   'august',
#   'small',
#   'coastal',
#   'resort',
#   'town',
#   'alicante',
#   'home',
#   'myriad',
#   'retiree',
#   'northern',
#   'central',
#   'europe',
#   'especially',
#   'united',
#   'kingdom',
#   'neighbourhood',
#   'particular',
#   'resident',
#   'speak',
#   'english',
#   'shop',
#   'english',
#   'name',
#   'effect',
#   'form',
#   'colony',
#   'commonly',
#   'hear',
#   'joke',
#   'xàbia',
#   'negotiation',
#   'gibraltar',
#   'prime',
#   'minister',
#   'margaret',
#   'thatcher',
#   'remark',
#   'will',
#   'gibraltar',
#   'leave',
#   'xàbia!',
#   'dictate',
#   'solidarity',
#   'individual',
#   'preserve',
#   'family',
#   'state',
#   'expectation',
#   'retiree',
#   'provide',
#   'support',
#   'family',
#   'typically',
#   'look',
#   'grandchild',
#   'reach',
#   'grander',
#   'age',
#   'count',
#   'child',
#   'care',
#   'model',
#   'base',
#   'member',
#   'family',
#   'live',
#   'relatively',
#   'close',
#   'proximity',
#   'lead',
#   'wonder',
#   'effect',
#   'distance',
#   'family',
#   'solidarity',
#   'be',
#   'follow',
#   'post',
#   'doctoral',
#   'programme',
#   'university',
#   'manchester',
#   'uk',
#   'virginia',
#   'tech',
#   'usa',
#   'coincidence',
#   'conspire',
#   'lead',
#   'xàbia',
#   'year',
#   'have',
#   'study',
#   'issue',
#   'stem',
#   'age',
#   'know',
#   'thank',
#   'literature',
#   'retiree',
#   'alicante',
#   'know',
#   'd',
#   'go',
#   'set',
#   'long',
#   'haul',
#   'contact',
#   'number',
#   'organisation',
#   'centre',
#   'retiree',
#   'include',
#   'regional',
#   'association',
#   'swiss',
#   'retiree',
#   'xàbia',
#   'happen',
#   'home',
#   'people',
#   'come',
#   'contact',
#   'touch',
#   'retiree',
#   'add',
#   'facebook',
#   'group',
#   'allow',
#   'extend',
#   'network',
#   'neighbouring',
#   'town',
#   'dénia',
#   'travel',
#   'month',
#   'half',
#   'stay',
#   'return',
#   'january',
#   'second',
#   'trip',
#   'husband',
#   'child',
#   'come',
#   'stay',
#   'speak',
#   'retiree',
#   'live',
#   'xàbia',
#   'spend',
#   'year',
#   'meet',
#   'public',
#   'home',
#   'depth',
#   'interview',
#   'able',
#   'analyse',
#   'nature',
#   'family',
#   'bond',
#   'maintain',
#   'live',
#   'far',
#   'away',
#   'accord',
#   'people',
#   'interview',
#   'finance',
#   'significant',
#   'factor',
#   'decision',
#   'leave',
#   'home',
#   'consider',
#   'improve',
#   'living',
#   'condition',
#   'retirement',
#   'migrate',
#   'abroad',
#   'fact',
#   'financial',
#   'situation',
#   'leave',
#   'little',
#   'choice',
#   'give',
#   'difference',
#   'purchase',
#   'power',
#   'retiree',
#   'able',
#   'buy',
#   'large',
#   'house',
#   'pool',
#   'eat',
#   'restaurant',
#   'necessarily',
#   'case',
#   'country',
#   'leave',
#   'aware',
#   'presence',
#   'help',
#   'hand',
#   'regional',
#   'economy',
#   'reinforce',
#   'idea',
#   'legitimately',
#   'home',
#   'open',
#   'talk',
#   'situation',
#   'proud',
#   'achieve',
#   'longer',
#   'feel',
#   'like',
#   'mouth',
#   'fed',
#   'literature',
#   'topic',
#   'generally',
#   'consider',
#   'retiree',
#   'individual',
#   'leave',
#   'enjoy',
#   'freedom',
#   'particularly',
#   'regard',
#   'family',
#   'duty',
#   'find',
#   'opposite',
#   'choose',
#   'spain',
#   'thailand',
#   'north',
#   'africa',
#   'far',
#   'family',
#   'agree',
#   'need',
#   'available',
#   'case',
#   'emergency',
#   'important',
#   'able',
#   'receive',
#   'family',
#   'member',
#   'guest',
#   'impression',
#   'offer',
#   'child',
#   'grandchildren',
#   'enjoyable',
#   'setting',
#   'holiday',
#   'bring',
#   'value',
#   'case',
#   'departure',
#   'cause',
#   'tension',
#   'child',
#   'expect',
#   'share',
#   'daily',
#   'chore',
#   'case',
#   'receive',
#   'support',
#   'family',
#   'interview',
#   'benjamin',
#   'keller'],
#  ['un',
#   'publish',
#   'global',
#   'sustainable',
#   'development',
#   'report',
#   'gsdr',
#   'peter',
#   'messerli',
#   'geographer',
#   'professor',
#   'sustainability',
#   'bern',
#   'member',
#   'independent',
#   'group',
#   'scientist',
#   'appoint',
#   'co',
#   'chair',
#   'schedule',
#   'tight',
#   'goal',
#   'ambitious',
#   'compensation',
#   'scientist',
#   'opportunity',
#   'exert',
#   'major',
#   'influence',
#   'world',
#   's',
#   'highest',
#   'rank',
#   'political',
#   'body',
#   'purpose',
#   'global',
#   'sustainable',
#   'development',
#   'report',
#   'united',
#   'nation',
#   'conference',
#   'sustainable',
#   'development',
#   'rio',
#   'member',
#   'state',
#   'un',
#   'decide',
#   'intensify',
#   'knowledge',
#   'exchange',
#   'politic',
#   'science',
#   'come',
#   'report',
#   'important',
#   'implement',
#   'monitor',
#   'development',
#   'goal',
#   'un',
#   's',
#   'agenda',
#   'simple',
#   'magic',
#   'formula',
#   'weigh',
#   'carefully',
#   'advantage',
#   'disadvantage',
#   'base',
#   'decision',
#   'fact',
#   'knowledge',
#   'manner',
#   'fair',
#   'decision',
#   'strategy',
#   'manage',
#   'herculean',
#   'task',
#   'want',
#   'divide',
#   'report',
#   'large',
#   'area',
#   'different',
#   'chapter',
#   'focus',
#   'analyse',
#   'interdependency',
#   'sustainability',
#   'goal',
#   'agenda',
#   'secondly',
#   'deal',
#   'implementation',
#   'process',
#   'change',
#   'possible',
#   'go',
#   'approach',
#   'thirdly',
#   'eye',
#   'open',
#   'new',
#   'topic',
#   'consider',
#   'agenda',
#   'fourthly',
#   'want',
#   'strengthen',
#   'voice',
#   'science',
#   'substantially',
#   'achieve',
#   'develop',
#   'implement',
#   'appropriate',
#   'method',
#   'find',
#   'solution',
#   'interface',
#   'politic',
#   'great',
#   'need',
#   'action',
#   'politic',
#   'science',
#   'report',
#   'destine',
#   'disappear',
#   'desk',
#   'drawer',
#   'contrary',
#   'voice',
#   'science',
#   'represent',
#   'table',
#   'head',
#   'state',
#   'member',
#   'country',
#   'meet',
#   'un',
#   'general',
#   'assembly',
#   'swiss',
#   'citizen',
#   'land',
#   'position',
#   'switzerland',
#   'hotspot',
#   'global',
#   'change',
#   'democratic',
#   'system',
#   'live',
#   'exchange',
#   'politic',
#   'science',
#   'people',
#   'science',
#   'represent',
#   'swiss',
#   'delegation',
#   'right',
#   'start',
#   'interview',
#   'rutishauser'],
#  ['illustrate',
#   'researcher',
#   'experience',
#   'work',
#   'image',
#   'photo',
#   'video',
#   'submit',
#   'new',
#   'snsf',
#   'competition',
#   'scientific',
#   'image',
#   'people',
#   'region',
#   'switzerland',
#   'take',
#   'total',
#   'image',
#   'video',
#   'submit',
#   'category',
#   'object',
#   'study',
#   'man',
#   'woman',
#   "science'",
#   'location',
#   'instruments',
#   'video',
#   'loop'],
#  ['switzerland',
#   'third',
#   'adult',
#   'overweight',
#   'despite',
#   'broad',
#   'base',
#   'campaign',
#   'counter',
#   'trend',
#   'upwards',
#   'mean',
#   'increase',
#   'risk',
#   'cardiovascular',
#   'disease',
#   'type',
#   'diabetes',
#   'mellitus',
#   'type',
#   'cancer',
#   'people',
#   'try',
#   'burn',
#   'excess',
#   'calorie',
#   'sport',
#   'majority',
#   'athletic',
#   'fellow',
#   'citizen',
#   'weight',
#   'control',
#   'move',
#   'order',
#   'help',
#   'group',
#   'lead',
#   'abdul',
#   'dulloo',
#   'professor',
#   'nutritional',
#   'physiology',
#   'university',
#   'fribourg',
#   'study',
#   'energy',
#   'expend',
#   'normal',
#   'activity',
#   'study',
#   'concentrate',
#   'intensive',
#   'activity',
#   'require',
#   'roughly',
#   'time',
#   'energy',
#   'lie',
#   'sit',
#   'everyday',
#   'life',
#   'rarely',
#   'time',
#   'level',
#   'intensity',
#   'team',
#   's',
#   'experiment',
#   'box',
#   'measuring',
#   'energy',
#   'consumption',
#   'stand',
#   'use',
#   'average',
#   'percent',
#   'energy',
#   'sit',
#   'find',
#   'stand',
#   'boost',
#   'energy',
#   'consumption',
#   'considerable',
#   'extent',
#   'people',
#   'activity',
#   'have',
#   'measure',
#   'people',
#   'consume',
#   'different',
#   'amount',
#   'energy',
#   'explain',
#   'dulloo',
#   'not',
#   'explain',
#   'away',
#   'age',
#   'weight',
#   'obese',
#   'people',
#   'display',
#   'different',
#   'degree',
#   'energy',
#   'consumption',
#   'researcher',
#   'try',
#   'find',
#   'answer',
#   'different',
#   'way',
#   'people',
#   'stand',
#   'people',
#   'use',
#   'energy',
#   'repeatedly',
#   'shift',
#   'weight',
#   'leg',
#   'answer',
#   'disappointingly',
#   'not',
#   'explain',
#   'difference',
#   'individual',
#   'order',
#   'burn',
#   'calorie',
#   'properly',
#   'people',
#   'step',
#   'dulloo',
#   'team',
#   'understand',
#   'small',
#   'difference',
#   'hop',
#   'able',
#   'individualise',
#   'strategy',
#   'counter',
#   'excess',
#   'weight',
#   'difficult',
#   'reach',
#   'right',
#   'people',
#   'national',
#   'health',
#   'campaign',
#   'sigrid',
#   'beer',
#   'institute',
#   'social',
#   'preventive',
#   'medicine',
#   'university',
#   'bern',
#   'preventive',
#   'measure',
#   'reach',
#   'member',
#   'population',
#   'affect',
#   'unaware',
#   'problem',
#   'treatment',
#   'today',
#   'start',
#   'consider',
#   'change',
#   'individual',
#   'behaviour',
#   'wrong',
#   'people',
#   'diet',
#   'trigger',
#   'increase',
#   'weight',
#   'later',
#   'people',
#   'normal',
#   'weight',
#   'reduce',
#   'lean',
#   'body',
#   'mass',
#   'body',
#   'counteract',
#   'save',
#   'energy',
#   'increase',
#   'energy',
#   'intake',
#   'dulloo',
#   'reduce',
#   'level',
#   'hormone',
#   'leptin',
#   'regulate',
#   'fat',
#   'metabolism',
#   'indirectly',
#   'hold',
#   'appetite',
#   'time',
#   'people',
#   'spend',
#   'hour',
#   'day',
#   'sit',
#   'computer',
#   'screen',
#   'experience',
#   'erosion',
#   'daily',
#   'physical',
#   'activity',
#   'try',
#   'compensate',
#   'sport',
#   'jog',
#   'little',
#   'sit',
#   'day',
#   'dulloo',
#   'j.',
#   'l.',
#   'mile',
#   'chan',
#   'et',
#   'al',
#   'stand',
#   'economy',
#   'heterogeneity',
#   'energy',
#   'cost',
#   'posture',
#   'maintenance',
#   'reside',
#   'differential',
#   'pattern',
#   'spontaneous',
#   'weight',
#   'shifting',
#   'european',
#   'journal',
#   'applied',
#   'physiology',
#   '2017)a',
#   'g.',
#   'dulloo',
#   'collateral',
#   'fattening',
#   'deficit',
#   'lean',
#   'body',
#   'mass',
#   'drive',
#   'overeat',
#   'obesity'],
#  ['sure',
#   'complain',
#   'high',
#   'comfort',
#   'level',
#   'wish',
#   'scientist',
#   'scholar',
#   'secure',
#   'job',
#   'important',
#   'recognise',
#   'area',
#   'irritation',
#   'especially',
#   'large',
#   'flexible',
#   'organisation',
#   'swiss',
#   'elite',
#   'react',
#   'small',
#   'signal',
#   'customarily',
#   'sovereign',
#   'manner',
#   'sustainable',
#   'educational',
#   'policy',
#   'mean',
#   'place',
#   'high',
#   'value',
#   'international',
#   'collaboration',
#   'experience',
#   'abroad',
#   'interdisciplinary',
#   'unconventional',
#   'project',
#   'high',
#   'degree',
#   'risk',
#   'tolerance',
#   'innovative',
#   'capacity',
#   'critical',
#   'discursive',
#   'culture',
#   'readiness',
#   'leave',
#   's',
#   'personal',
#   'comfort',
#   'zone',
#   'especially',
#   'need',
#   'kind',
#   'performer',
#   'career',
#   'found',
#   'precisely',
#   'criterion',
#   'order',
#   'compete',
#   'internationally',
#   'researcher',
#   'good',
#   'orient',
#   'accord',
#   'dynamic',
#   'development',
#   'process',
#   'instead',
#   'take',
#   'delight',
#   'status',
#   'quo',
#   'funding',
#   'body',
#   'future',
#   'create',
#   'necessary',
#   'incentive',
#   'support',
#   'inconvenient',
#   'maverick',
#   'special',
#   'thirst',
#   'knowledge',
#   'achievement',
#   'ulf',
#   'büntgen',
#   'professor',
#   'environmental',
#   'system',
#   'analysis',
#   'department',
#   'geography',
#   'university',
#   'cambridge',
#   'january',
#   'senior',
#   'scientist',
#   'swiss',
#   'federal',
#   'institute',
#   'forest',
#   'snow',
#   'landscape',
#   'wsl',
#   'year'],
#  ['mouse',
#   'encounter',
#   'snake',
#   'decide',
#   'flash',
#   'action',
#   'offer',
#   'good',
#   'chance',
#   'survival',
#   'enter',
#   'paralytic',
#   'shock',
#   'invisible',
#   'predator',
#   'flee',
#   'quickly',
#   'possible',
#   'decision',
#   'consciously',
#   'determine',
#   'multitude',
#   'factor',
#   'distance',
#   'mouse',
#   'snake',
#   'availability',
#   'away',
#   'route',
#   'previous',
#   'experience',
#   'state',
#   'health',
#   'mouse',
#   'circuit',
#   'brain',
#   'important',
#   'life',
#   'death',
#   'decision',
#   'locate',
#   'almond',
#   'shape',
#   'area',
#   'call',
#   'amygdala',
#   'information',
#   'influence',
#   'behavioural',
#   'reaction',
#   'channel',
#   'varied',
#   'region',
#   'brain',
#   'amygdala',
#   'process',
#   'explain',
#   'neuroscientist',
#   'andrea',
#   'lüthi',
#   'work',
#   'group',
#   'friedrich',
#   'miescher',
#   'institute',
#   'biomedical',
#   'basel',
#   'investigate',
#   'process',
#   'occur',
#   'mouse',
#   's',
#   'amygdala',
#   'lüthi',
#   'researcher',
#   'especially',
#   'interested',
#   'decision',
#   'completely',
#   'different',
#   'form',
#   'behaviour',
#   'passive',
#   'paralytic',
#   'shock',
#   'active',
#   'flight',
#   'order',
#   'find',
#   'train',
#   'test',
#   'animal',
#   'fall',
#   'paralytic',
#   'shock',
#   'hear',
#   'pure',
#   'tone',
#   'display',
#   'flight',
#   'behaviour',
#   'hear',
#   'mixture',
#   'tone',
#   'genetic',
#   'procedure',
#   'alter',
#   'behaviour',
#   'different',
#   'type',
#   'nerve',
#   'cell',
#   'amygdala',
#   'hinder',
#   'mouse',
#   'expose',
#   'yellow',
#   'light',
#   'researcher',
#   'possible',
#   'switch',
#   'specific',
#   'group',
#   'nerve',
#   'observe',
#   'impact',
#   'behaviour',
#   'mouse',
#   'experiment',
#   'demonstrate',
#   'group',
#   'nerve',
#   'cell',
#   'control',
#   'fear',
#   'behaviour',
#   'group',
#   'responsible',
#   'trigger',
#   'paralytic',
#   'shock',
#   'trigger',
#   'flight',
#   'switch',
#   'amygdala',
#   'turn',
#   'way',
#   'lüthi',
#   'furthermore',
#   'nerve',
#   'group',
#   'closely',
#   'link',
#   'activate',
#   'paralytic',
#   'shock',
#   'hinder',
#   'flight',
#   'response',
#   'vice',
#   'versa',
#   'prevent',
#   'amygdala',
#   'give',
#   'order',
#   'contradictory',
#   'form',
#   'behaviour',
#   'muscle',
#   'case',
#   'type',
#   'nerve',
#   'cell',
#   'work',
#   'contrary',
#   'trigger',
#   'clear',
#   'reaction',
#   'explain',
#   'fritjof',
#   'helmchen',
#   'director',
#   'institute',
#   'brain',
#   'university',
#   'zurich',
#   'experiment',
#   'perfect',
#   'example',
#   'use',
#   'new',
#   'method',
#   'study',
#   'live',
#   'non',
#   'sedate',
#   'animal',
#   'find',
#   'component',
#   'circuit',
#   'nerve',
#   'cell',
#   'determine',
#   'specific',
#   'pattern',
#   'behaviour',
#   'helmchen',
#   'involve',
#   'study',
#   'believe',
#   'finding',
#   'type',
#   'experiment',
#   'find',
#   'application',
#   'human',
#   'medicine',
#   'come',
#   'decade',
#   'mental',
#   'illness',
#   'arise',
#   'altered',
#   'circuitry',
#   'misdirect',
#   'information',
#   'flow',
#   'brain',
#   'lüthi',
#   'believe',
#   'result',
#   'essentially',
#   'transferable',
#   'human',
#   'structure',
#   'amygdala',
#   'largely',
#   'retain',
#   'process',
#   'evolution',
#   'construct',
#   'way',
#   'human',
#   'mouse',
#   'anxiety',
#   'disorder',
#   'people',
#   'occur',
#   'old',
#   'system',
#   'dominate',
#   'difficult',
#   'control',
#   'consciously',
#   'observe',
#   'human',
#   'pattern',
#   'behaviour',
#   'far',
#   'complex',
#   'varied',
#   'people',
#   'consciously',
#   'big',
#   'risk',
#   'order',
#   'discover',
#   'new',
#   'thing',
#   'draw',
#   'advantage',
#   'poor',
#   'strategy',
#   'little',
#   'mouse',
#   'j.',
#   'fadok',
#   's.',
#   'krabbe',
#   'm.',
#   'markovic',
#   'j.',
#   'courtin',
#   'c.',
#   'xu',
#   'l.',
#   'massi',
#   'p.',
#   'botta',
#   'k.',
#   'bylund',
#   'c.',
#   'müller',
#   'a.',
#   'kovacevic',
#   'p.',
#   'tovote',
#   'a.',
#   'lüthi',
#   'competitive',
#   'inhibitory',
#   'circuit',
#   'selection',
#   'active',
#   'passive',
#   'fear',
#   'response',
#   'nature'],
#  ['climate',
#   'stress',
#   'weaken',
#   'microbial',
#   'community',
#   'soil',
#   'lower',
#   'ability',
#   'absorb',
#   'nitrogen',
#   'surrounding',
#   'nicolas',
#   'legay',
#   'main',
#   'author',
#   'study',
#   'plant',
#   'require',
#   'nitrogen',
#   'grow',
#   'micro',
#   'organism',
#   'suddenly',
#   'competitive',
#   'plant',
#   'find',
#   'soil',
#   'rich',
#   'grow',
#   'good',
#   'researcher',
#   'subject',
#   'plant',
#   'afresh',
#   'drought',
#   'condition',
#   'produce',
#   'great',
#   'volume',
#   'fodder',
#   'microbial',
#   'community',
#   'suffer',
#   'short',
#   'term',
#   'effect',
#   'legay',
#   'add',
#   'micro',
#   'organism',
#   'soil',
#   'highly',
#   'susceptible',
#   'drought',
#   'long',
#   'term',
#   'responsible',
#   'recycle',
#   'soil',
#   'nutrient',
#   'time',
#   'go',
#   'soil',
#   'quality',
#   'actually',
#   'decline',
#   'overall',
#   'quantity',
#   'fodder',
#   'produce',
#   'study',
#   'large',
#   'european',
#   'project',
#   'investigate',
#   'impact',
#   'moderate',
#   'agricultural',
#   'practice',
#   'light',
#   'fertilisation',
#   'harvesting',
#   'comparison',
#   'intensive',
#   'farming',
#   'legay',
#   'frequency',
#   'climate',
#   'event',
#   'increase',
#   'traditional',
#   'farming',
#   'practice',
#   'difficult',
#   'sustain',
#   'absence',
#   'soil',
#   'amendment'],
#  ['pharmacologist',
#   'green',
#   'fluorescent',
#   'blood',
#   'vessel',
#   'carry',
#   'test',
#   'zebrafish',
#   'embryo',
#   'zebrafish',
#   'ethically',
#   'problematical',
#   'rodent',
#   'highly',
#   'develop',
#   'zebrafish',
#   'embryo',
#   'fascinating',
#   'advantage',
#   'transparent',
#   'mean',
#   'team',
#   'observe',
#   'live',
#   'organism',
#   'nanotransporter',
#   'mark',
#   'red',
#   'fluorescent',
#   'colour',
#   'spread',
#   'blood',
#   'vessel',
#   'transpire',
#   'tiny',
#   'difference',
#   'structure',
#   'major',
#   'impact',
#   'distribution',
#   'organism',
#   'extremely',
#   'difficult',
#   'today',
#   'predict',
#   'nanotransporter',
#   'behave',
#   'organism',
#   'researcher',
#   'hope',
#   'test',
#   'zebrafish',
#   'embryo',
#   'enable',
#   'find',
#   'nanotransporter',
#   'construct',
#   'deliver',
#   'big',
#   'possible',
#   'cargo',
#   'sick',
#   'cell',
#   'leave',
#   'healthy',
#   'tissue',
#   'untouched',
#   'zebrafish',
#   'model',
#   'intend',
#   'help',
#   'identify',
#   'promising',
#   'candidate',
#   'number',
#   'different',
#   'transporter',
#   'embark',
#   'complex',
#   'series',
#   'test',
#   'rodent',
#   'witzigmann'],
#  ['malaspinas',
#   'year',
#   'old',
#   'study',
#   'ancestor',
#   'populate',
#   'planet',
#   'particular',
#   'look',
#   'leave',
#   'africa',
#   'adapt',
#   'new',
#   'environment',
#   'point',
#   'history',
#   'event',
#   'occur',
#   'bear',
#   'turn',
#   'contemporary',
#   'ancient',
#   'dna',
#   'sample',
#   'hold',
#   'museum',
#   'analyse',
#   'mathematical',
#   'digital',
#   'model',
#   'example',
#   'team',
#   'analyse',
#   'hypothesis',
#   'transpacific',
#   'contact',
#   'polynesia',
#   'america',
#   'project',
#   'lead',
#   'ancient',
#   'dna',
#   'sample',
#   'easter',
#   'island',
#   'project',
#   'travel',
#   'south',
#   'america',
#   'response',
#   'phone',
#   'national',
#   'museum',
#   'rio',
#   'de',
#   'janeiro',
#   'brazil',
#   'correspondent',
#   'study',
#   'human',
#   'remain',
#   'note',
#   'genome',
#   'certain',
#   'individual',
#   'local',
#   'population',
#   'live',
#   'century',
#   'entirely',
#   'polynesian',
#   'malaspina',
#   'bear',
#   'geneva',
#   'grow',
#   'sibling',
#   'parent',
#   'physicist',
#   'father',
#   'greek',
#   'artist',
#   'mother',
#   'spend',
#   'month',
#   'crete',
#   'godfather',
#   'chemist',
#   'university',
#   'heraklion',
#   'laboratory',
#   'ask',
#   'question',
#   'fascinate',
#   'freedom',
#   'work',
#   'spend',
#   'month',
#   'think',
#   'question',
#   'discuss',
#   'idea',
#   'experiment',
#   'begin',
#   'realise',
#   'want',
#   'think',
#   'study',
#   'law',
#   'literature',
#   'decide',
#   'medicine',
#   'meet',
#   'enrolment',
#   'deadline',
#   'settle',
#   'biology',
#   'physics',
#   'study',
#   'simultaneously',
#   'class',
#   'evolution',
#   'life',
#   'change',
#   'moment',
#   'point',
#   'realise',
#   'want',
#   'study',
#   'population',
#   'genetic',
#   'love',
#   'set',
#   'bearing',
#   'california',
#   'begin',
#   'ph.d',
#   'prestigious',
#   'university',
#   'berkeley',
#   'not',
#   'afraid',
#   'not',
#   'delay',
#   'throw',
#   'swimming',
#   'costume',
#   'suitcase',
#   'left',
#   'thinking',
#   'berkeley',
#   'close',
#   'los',
#   'angele',
#   'san',
#   'francisco',
#   'return',
#   'switzerland',
#   'have',
#   'spend',
#   'time',
#   'denmark',
#   'malaspina',
#   'describe',
#   'professional',
#   'career',
#   'would',
#   'long',
#   'streak',
#   'good',
#   'luck',
#   'owe',
#   'current',
#   'position',
#   'fairy',
#   'godmother',
#   'postdoctoral',
#   'supervisor',
#   'copenhagen',
#   'eske',
#   'willerslev',
#   'see',
#   'thing',
#   'differently',
#   'build',
#   'career',
#   'basis',
#   'brilliant',
#   'intelligence',
#   'enormous',
#   'work',
#   'ethic',
#   'university',
#   'bern',
#   'specialist',
#   'population',
#   'genetic',
#   'laurent',
#   'excoffi',
#   'applaud',
#   'capacity',
#   'link',
#   'theoretical',
#   'study',
#   'empirical',
#   'datum',
#   'rare',
#   'people',
#   'develop',
#   'implement',
#   'model',
#   'collect',
#   'analyse',
#   'sample',
#   'take',
#   'ground',
#   'verify',
#   'theory',
#   'play',
#   'set',
#   'museum',
#   'group',
#   'visitor',
#   'guide',
#   'young',
#   'scientist',
#   'introduce',
#   'work',
#   'dna',
#   'audience',
#   'take',
#   'journey',
#   'start',
#   'human',
#   'leave',
#   'africa',
#   'end',
#   'arrival',
#   'australia',
#   'encounter',
#   'aboriginal',
#   'population',
#   'want',
#   'science',
#   'career',
#   'fun',
#   'time',
#   'want',
#   'publicise',
#   'work',
#   'explain',
#   'genome',
#   'contain',
#   'history',
#   'ancestor',
#   'underscore',
#   'relative',
#   'migrant',
#   'way',
#   'hope',
#   'draw',
#   'people',
#   's',
#   'attention',
#   'fate',
#   'indigenous',
#   'population',
#   'way',
#   'society'],
#  ['year',
#   'doctor',
#   'world',
#   'implant',
#   'cardiac',
#   'pacemaker',
#   'routine',
#   'operation',
#   'year',
#   'later',
#   'tiny',
#   'device',
#   'need',
#   'new',
#   'battery',
#   'new',
#   'operation',
#   'come',
#   'risk',
#   'complication',
#   'reason',
#   'biomedical',
#   'engineer',
#   'adrian',
#   'zurbuchen',
#   'work',
#   'autonomous',
#   'pacemaker',
#   'work',
#   'battery',
#   'order',
#   'push',
#   'litre',
#   'blood',
#   'body',
#   'minute',
#   'heart',
#   'pump',
#   'capacity',
#   'roughly',
#   'watt',
#   'pacemaker',
#   'contrast',
#   'require',
#   'microwatt',
#   'fraction',
#   'energy',
#   'produce',
#   'muscle',
#   'vivo',
#   'experiment',
#   'pig',
#   'zurbuchen',
#   'team',
#   'manage',
#   'produce',
#   'microwatt',
#   'power',
#   'heartbeat',
#   'minute',
#   'sufficient',
#   'zurbuchen',
#   'run',
#   'simulation',
#   'calculate',
#   'parameter',
#   'harvester',
#   'alter',
#   'order',
#   'run',
#   'energy',
#   'available',
#   'alexandra',
#   'bröhm'],
#  ['think',
#   'animal',
#   'suffer',
#   'science',
#   'laboratory',
#   'queasy',
#   'feeling',
#   'stomach',
#   'carry',
#   'animal',
#   'test',
#   'fun',
#   'knowledge',
#   'gain',
#   'time',
#   'result',
#   'medical',
#   'progress',
#   'veterinary',
#   'science',
#   'legislator',
#   'take',
#   'account',
#   'ethical',
#   'dilemma',
#   'arise',
#   'weigh',
#   'possible',
#   'benefit',
#   'humankind',
#   'suffering',
#   'animal',
#   'accord',
#   'law',
#   'animal',
#   'test',
#   'limit',
#   'strictly',
#   'indispensable'],
#  ['today',
#   's',
#   'world',
#   'increasingly',
#   'dominate',
#   'emotion',
#   'slogan',
#   'imagery',
#   'use',
#   'factual',
#   'argumentation',
#   'struggle',
#   'punch',
#   'weight',
#   'tom',
#   'nichols',
#   'prosperity',
#   'fault',
#   'steep',
#   'abundance',
#   'tend',
#   'forget',
#   'basis',
#   'health',
#   'comfort',
#   'opinion',
#   'fact',
#   'give',
#   'hardly',
#   'option',
#   'address',
#   'society',
#   's',
# ...
#   'hairbrush',
#   'kitchen',
#   'whisk',
#   'select',
#   'image',
#   'arbitrarily',
#   'designate',
#   'correct',
#   'reward',
#   'receive',
#   'piece',
#   'fruit',
#   'experiment',
#   'computer',
#   'make',
#   'sound',
#   'image',
#   'present',
#   'food',
#   'quick',
#   'blow',
#   'hammer',
#   'look',
#   'test',
#   'necessary',
#   'retain',
#   'right',
#   'image',
#   'preliminary',
#   'result',
#   'suggest',
#   'food',
#   'help',
#   'memorise',
#   'information',
#   'faster',
#   'remain',
#   'confirm',
#   'session',
#   'stay',
#   'screen',
#   'reward',
#   'right',
#   'time',
#   'direct',
#   'contact',
#   'work',
#   'zoo',
#   'keeper',
#   'present',
#   'aim',
#   'guarantee',
#   'good',
#   'level',
#   'safety',
#   'avoid',
#   'subject',
#   'animal',
#   'stress',
#   'have',
#   'previously',
#   'study',
#   'dingo',
#   'australian',
#   'wildlife',
#   'reserve',
#   'zoo',
#   'guarantee',
#   'able',
#   'work',
#   'animal',
#   'hour',
#   'time',
#   'instead',
#   'have',
#   'hike',
#   'hour',
#   'forest',
#   'sure',
#   'find',
#   'subject',
#   'downside',
#   'zoo',
#   'population',
#   'small',
#   'not',
#   'grow',
#   'natural',
#   'environment',
#   'certain',
#   'rule',
#   'example',
#   'animal',
#   'separate',
#   'work',
#   'depend',
#   'lot',
#   'mood',
#   'subject',
#   'participation',
#   'voluntary',
#   'zoo',
#   'keeper',
#   'agree',
#   'maximum',
#   'length',
#   '15-minute',
#   'session',
#   'day',
#   'red',
#   'background',
#   'screen',
#   'indicate',
#   'chimpanzee',
#   'reach',
#   'limit',
#   'important',
#   'term',
#   'diet',
#   'proper',
#   'functioning',
#   'group',
#   'apes',
#   'eat',
#   'behaviour',
#   'disturb',
#   'reward',
#   'conflict',
#   'arise',
#   'access',
#   'screen',
#   'currently',
#   'disposal',
#   'adult',
#   'individual',
#   'acquire',
#   'sufficient',
#   'level',
#   'work',
#   'progress',
#   'female',
#   'show',
#   'interest',
#   'screen',
#   'hopeful',
#   'day',
#   'participate',
#   'aware',
#   'neophobic',
#   'nature',
#   'chimpanzee',
#   'surprised',
#   'take',
#   'week',
#   'encourage',
#   'touch',
#   'screen',
#   'despite',
#   'piece',
#   'carrot',
#   'place',
#   'work',
#   'chimpanzee',
#   'push',
#   'constantly',
#   'rethink',
#   'task',
#   'try',
#   'smart',
#   'easy',
#   'way',
#   'get',
#   'reward',
#   'effort',
#   'find',
#   'example',
#   'female',
#   's',
#   'task',
#   'press',
#   'square',
#   'move',
#   'random',
#   'trajectory',
#   'soon',
#   'work',
#   'press',
#   'spot',
#   'repeatedly',
#   'square',
#   'eventually',
#   'pass',
#   'finger',
#   'case',
#   'adapt',
#   'change',
#   'computer',
#   'program',
#   'fair',
#   'share',
#   'amusing',
#   'moment',
#   'day',
#   'female',
#   'cover',
#   'clothe',
#   'handful',
#   'excrement',
#   'throw',
#   'grate',
#   'right',
#   'visitor',
#   'start',
#   'ask',
#   'question',
#   'work',
#   'smell',
#   'bad',
#   'hardly',
#   'straight',
#   'face',
#   'currently',
#   'conduct',
#   'second',
#   'study',
#   'determine',
#   'food',
#   'call',
#   'influence',
#   'individual',
#   's',
#   'behaviour',
#   'unknown',
#   'food',
#   'ultimate',
#   'goal',
#   'study',
#   'apes',
#   'communication',
#   'skill',
#   'better',
#   'understand',
#   'evolution',
#   'human',
#   'language',
#   'interview',
#   'martine',
#   'brocard'],
#  ['laugh',
#   'joke',
#   'issue',
#   'tidal',
#   'wave',
#   'doubt',
#   'sweep',
#   'away',
#   'certainty',
#   'science',
#   'carry',
#   'conflicting',
#   'result',
#   'political',
#   'attack',
#   'shake',
#   'confidence',
#   'have',
#   'drag',
#   'situation',
#   'expertise',
#   'guide',
#   'individual',
#   'collective',
#   'choice',
#   'citizen',
#   'leave',
#   'deafen',
#   'cacophony',
#   'opinion',
#   'state',
#   'affair',
#   'see',
#   'good',
#   'light',
#   'reconciliation',
#   'doubt',
#   'actually',
#   'heart',
#   'science',
#   'clarification',
#   'disagreement',
#   'knowledge',
#   'construct',
#   'uncovering',
#   'conflict',
#   'interest',
#   'present',
#   'expert',
#   'report',
#   'lead',
#   'mature',
#   'naïve',
#   'relationship',
#   'science',
#   'society',
#   'relationship',
#   'scientist',
#   'bear',
#   'little',
#   'responsibility',
#   'transmit',
#   'truth',
#   'instead',
#   'involved',
#   'democratic',
#   'game',
#   'happen',
#   'understand',
#   'situation',
#   'source',
#   'know',
#   'evidence',
#   'base',
#   'policy',
#   'swiss',
#   'political',
#   'scientist',
#   'caroline',
#   'schlaufer',
#   'currently',
#   'hold',
#   'position',
#   'high',
#   'school',
#   'economic',
#   'moscow',
#   'term',
#   'appear',
#   'great',
#   'britain',
#   '1990',
#   'tony',
#   'blair',
#   's',
#   'government',
#   'describe',
#   'intention',
#   'authority',
#   'base',
#   'action',
#   'empirically',
#   'prove',
#   'fact',
#   'ideology',
#   'belief',
#   'expression',
#   'fashionable',
#   'social',
#   'science',
#   'finally',
#   'decide',
#   'look',
#   'scientific',
#   'datum',
#   'policy',
#   'question',
#   'public',
#   'confidence',
#   'expert',
#   'subject',
#   'empirical',
#   'check',
#   'idea',
#   'swiss',
#   'science',
#   'barometer',
#   'conduct',
#   'university',
#   'zurich',
#   'fribourg',
#   'measure',
#   'people',
#   's',
#   'attitude',
#   'scientific',
#   'knowledge',
#   'result',
#   'comforting',
#   'confidence',
#   'science',
#   'high',
#   'julia',
#   'metag',
#   'co',
#   'director',
#   'project',
#   'switzerland',
#   'little',
#   'high',
#   'country',
#   'measure',
#   'majority',
#   'population',
#   'agree',
#   'political',
#   'decision',
#   'base',
#   'scientific',
#   'result',
#   'add',
#   'proviso',
#   'trust',
#   'scientist',
#   'employ',
#   'industry',
#   'low',
#   'trust',
#   'work',
#   'university',
#   'area',
#   'polarise',
#   'public',
#   'opinion',
#   'mistrust',
#   'remotely',
#   'related',
#   'animal',
#   'experimentation',
#   'barometer',
#   's',
#   'datum',
#   'stretch',
#   'beginning',
#   'era',
#   'donald',
#   'trump',
#   'post',
#   'truth',
#   'fake',
#   'news',
#   'situation',
#   'worsen',
#   'united',
#   'state',
#   'science',
#   'engineering',
#   'indicator',
#   'survey',
#   'measure',
#   'variable',
#   'barometer',
#   'show',
#   'scientist',
#   'remain',
#   'trust',
#   'group',
#   'society',
#   'metag',
#   'country',
#   'united',
#   'state',
#   'germany',
#   'longitudinal',
#   'datum',
#   'available',
#   'confidence',
#   'remain',
#   'stable',
#   'decade',
#   'not',
#   'sign',
#   'collapse',
#   'readily',
#   'evoke',
#   'medium',
#   'crisis',
#   'perception',
#   'come',
#   'opinion',
#   'new',
#   'phenomenon',
#   'schlaufer',
#   'expert',
#   'bashing',
#   'activity',
#   'common',
#   'certain',
#   'political',
#   'movement',
#   'response',
#   'attack',
#   'past',
#   'year',
#   'scientist',
#   'feel',
#   'need',
#   'raise',
#   'voice',
#   'political',
#   'arena',
#   'present',
#   'medium',
#   'defend',
#   'work',
#   'accord',
#   'schlaufer',
#   'recent',
#   'phenomenon',
#   'necessarily',
#   'reflect',
#   'grow',
#   'politicisation',
#   'expertise',
#   'current',
#   'exacerbation',
#   'give',
#   'great',
#   'visibility',
#   'old',
#   'fact',
#   'expertise',
#   'long',
#   'politicise',
#   'crisis',
#   'deplore',
#   'sense',
#   'scholarly',
#   'controversy',
#   'reflection',
#   'oppose',
#   'world',
#   'view',
#   'societal',
#   'project',
#   'neutral',
#   'take',
#   'place',
#   'upstream',
#   'generally',
#   'not',
#   'mean',
#   'definition',
#   'problem',
#   'want',
#   'study',
#   'schlaufer',
#   'accord',
#   'sheila',
#   'jasanoff',
#   'founding',
#   'figure',
#   'sociology',
#   'science',
#   'professor',
#   'harvard',
#   'university',
#   'represent',
#   'calling',
#   'question',
#   'recently',
#   'term',
#   'founding',
#   'myth',
#   'expert',
#   'authority',
#   'separation',
#   'fact',
#   'value',
#   'time',
#   'reconfiguration',
#   'relationship',
#   'science',
#   'society',
#   'take',
#   'place',
#   'great',
#   'effort',
#   'decade',
#   'country',
#   'develop',
#   'form',
#   'debate',
#   'scientist',
#   'public',
#   'note',
#   'chilver',
#   'preparation',
#   'climate',
#   'conference',
#   'copenhagen',
#   'paris',
#   'example',
#   'series',
#   'citizen',
#   'deliberation',
#   'session',
#   'way',
#   'show',
#   'citizen',
#   'capable',
#   'make',
#   'sensible',
#   'judgment',
#   'highly',
#   'technical',
#   'issue',
#   'participatory',
#   'approach',
#   'grey',
#   'area',
#   'chilver',
#   'public',
#   'define',
#   'problem',
#   'consequently',
#   'process',
#   'aim',
#   'because',
#   'behavioural',
#   'change',
#   'population',
#   'way',
#   'define',
#   'desirable',
#   'advance',
#   'public',
#   'authority',
#   'policy',
#   'soft',
#   'persuasion',
#   'know',
#   'decade',
#   'nudging',
#   'individual',
#   'lead',
#   'adopt',
#   'practice',
#   'appear',
#   'result',
#   'personal',
#   'choice',
#   'constraint',
#   'underlie',
#   'crisis',
#   'expertise',
#   'phenomenon',
#   'broad',
#   'movement',
#   'accept',
#   'uncertainty',
#   'modify',
#   'mutual',
#   'expectation',
#   'expert',
#   'public',
#   'propose',
#   'renew',
#   'role',
#   'scientist',
#   'communicate',
#   'finding',
#   'metag',
#   'talk',
#   'process',
#   'construct',
#   'result',
#   'express',
#   'opinion',
#   'engage',
#   'discussion',
#   'public',
#   'possible',
#   'resist',
#   'temptation',
#   'withdraw',
#   'debate',
#   'spite',
#   'study',
#   'misuse',
#   'medium',
#   'good',
#   'view',
#   'science',
#   'work',
#   'limit',
#   'margin',
#   'error',
#   'continue',
#   'play',
#   'role',
#   'safeguard',
#   'add',
#   'schlaufer',
#   'political',
#   'authority',
#   'commission',
#   'study',
#   'hide',
#   'result',
#   'fail',
#   'meet',
#   'expectation',
#   'general',
#   'study',
#   'end',
#   'hand',
#   'press',
#   'public',
#   'conclusion',
#   'naïve',
#   'think',
#   'scientific',
#   'evidence',
#   'result',
#   'decisive',
#   'factor',
#   'democratic',
#   'process',
#   'happen',
#   'accord',
#   'schlaufer',
#   'individual',
#   'collective',
#   'decision',
#   'need',
#   'fact',
#   'produce',
#   'fact',
#   'mean',
#   'turn',
#   'increasingly',
#   'expert',
#   'choice',
#   'board',
#   'value',
#   'interest',
#   'opinion',
#   'day',
#   'day',
#   'experience',
#   'web',
#   'element',
#   'root',
#   'outside',
#   'purity',
#   'empirical',
#   'evidence',
#   'reasoning'],
#  ['arctic',
#   'fox',
#   'not',
#   'long',
#   'desert',
#   'desert',
#   'fox',
#   'arctic',
#   'animal',
#   'cold',
#   'region',
#   'earth',
#   'grow',
#   'big',
#   'warm',
#   'clime',
#   'related',
#   'specie',
#   'ear',
#   'small',
#   'because',
#   'evolutionary',
#   'adjustment',
#   'lie',
#   'temperature',
#   'balance',
#   'large',
#   'volume',
#   'small',
#   'surface',
#   'area',
#   'mean',
#   'warmth',
#   'lose',
#   'small',
#   'bodily',
#   'extremity',
#   'prevent',
#   'heat',
#   'loss',
#   'reason',
#   'physiological',
#   'reaction',
#   'local',
#   'temperature',
#   'patrick',
#   'rohner',
#   'primary',
#   'author',
#   'study',
#   'insect',
#   'grow',
#   'slower',
#   'get',
#   'cold',
#   'time',
#   'development',
#   'time',
#   'extend',
#   'balance',
#   'large',
#   'size',
#   'provide',
#   'fly',
#   'evolutionary',
#   'advantage',
#   'cold',
#   'unclear',
#   'rohner',
#   'cold',
#   'region',
#   'flies',
#   'wing',
#   'longer',
#   'converse',
#   'rule',
#   'warm',
#   'blooded',
#   'creature',
#   'rohner',
#   'explain',
#   'short',
#   'wing',
#   'effect',
#   'temperature',
#   'balance',
#   'creature',
#   'fly',
#   'small',
#   'immediately',
#   'outside',
#   'temperature',
#   'long',
#   'wing',
#   'clear',
#   'advantage',
#   'calculation',
#   'show',
#   'help',
#   'fly',
#   'generate',
#   'thrust',
#   'energy',
#   'mean',
#   'air',
#   'low',
#   'temperature',
#   'try',
#   'find',
#   'warm',
#   'spot',
#   'example'],
#  ['switzerland',
#   's',
#   'relationship',
#   'subsoil',
#   'swiss',
#   'obsession',
#   'tunnel',
#   'obviously',
#   'economic',
#   'aspect',
#   'know',
#   'export',
#   'market',
#   'value',
#   'prove',
#   'underground',
#   'nuclear',
#   'fallout',
#   'shelter',
#   'cold',
#   'war',
#   'partly',
#   'result',
#   'cement',
#   'industry',
#   'lobbying',
#   'parliamentarian',
#   'mandatory',
#   'construction',
#   'second',
#   'world',
#   'war',
#   'swiss',
#   'population',
#   'convince',
#   'end',
#   'national',
#   'redoubt',
#   'mistakenly',
#   'double',
#   'imagery',
#   'connect',
#   'world',
#   'underground',
#   'hand',
#   'time',
#   'sumerian',
#   'home',
#   'dead',
#   'place',
#   'god',
#   'hero',
#   'survive',
#   'gilgamesh',
#   'amon',
#   'ra',
#   'orpheus',
#   'hand',
#   'positive',
#   'image',
#   'underground',
#   'world',
#   'place',
#   'preserve',
#   'place',
#   'gestation',
#   'renew',
#   'society',
#   'emerge',
#   'condition',
#   'ground',
#   'favourable',
#   'everyday',
#   'term',
#   'image',
#   'come',
#   'life',
#   'switzerland',
#   's',
#   'traditional',
#   'carnotzet',
#   'furnished',
#   'wine',
#   'cellar',
#   'host',
#   'social',
#   'event',
#   'individual',
#   'work',
#   'time',
#   'cut',
#   'outside',
#   'world',
#   'surround',
#   'group',
#   'friend',
#   'place',
#   'swiss',
#   'people',
#   'build',
#   'inner',
#   'character',
#   'excessive',
#   'recourse',
#   'behaviour',
#   'lead',
#   'particular',
#   'form',
#   'claustrophobia',
#   'observe',
#   'board',
#   'submarine',
#   'people',
#   'confine',
#   'long',
#   'period',
#   'irritability',
#   'obsessive',
#   'disorder',
#   'paranoia',
#   'trap',
#   'end',
#   'carnotzet',
#   'follow',
#   'alpine',
#   'tunnel',
#   'national',
#   'redoubt',
#   'plethora',
#   'fallout',
#   'shelter',
#   'switzerland',
#   'continue',
#   'privilege',
#   'subsoil',
#   'renew',
#   'vigour',
#   'today',
#   'form',
#   'datum',
#   'storage',
#   'switzerland',
#   'currently',
#   'position',
#   'data',
#   'security',
#   'market',
#   'example',
#   'ticino',
#   'base',
#   'company',
#   'dataverna',
#   'buy',
#   'service',
#   'tunnel',
#   'bore',
#   'construction',
#   'gotthard',
#   'base',
#   'tunnel',
#   'instal',
#   'computer',
#   'server',
#   'term',
#   'datum',
#   'mining',
#   'time',
#   'describe',
#   'exploration',
#   'exploitation',
#   'datum',
#   'metaphor',
#   'reality',
#   'point',
#   'view',
#   'physical',
#   'world',
#   'fall',
#   'neatly',
#   'boundary',
#   'metaphor',
#   'see',
#   'angle',
#   'portray',
#   'material',
#   'attachment',
#   'object',
#   'imbue',
#   'ancient',
#   'imagination',
#   'past',
#   'custom',
#   'endure',
#   'determine',
#   'way',
#   'thinking',
#   'case',
#   'everyday',
#   'object',
#   'example',
#   'layout',
#   'computer',
#   'keyboard',
#   'result',
#   'physical',
#   'constraint',
#   'typewriter',
#   'hammer',
#   'entangle',
#   'certain',
#   'letter',
#   'set',
#   'close',
#   'material',
#   'property',
#   'object',
#   'old',
#   'social',
#   'practice',
#   'continually',
#   'imprint',
#   'mind',
#   'behaviour',
#   'impact',
#   'imprint',
#   'typically',
#   'observe',
#   'tunnel',
#   'work',
#   'postcarworld',
#   'project',
#   'epfl',
#   'explore',
#   'hypothesis',
#   'car',
#   'free',
#   'world',
#   'recognise',
#   'new',
#   'tunnel',
#   'car',
#   'gotthard',
#   'vote',
#   'way',
#   'condemn',
#   'tunnel',
#   'profitable',
#   'vote',
#   'tunnel',
#   'drive',
#   'car',
#   'continue',
#   'drive',
#   'long',
#   'distance',
#   'tunnel',
#   'reality',
#   'logic',
#   'specific',
#   'ancestor',
#   'lead',
#   'bore',
#   'hole',
#   'alp',
#   'place',
#   'find',
#   'practice',
#   'make',
#   'physical',
#   'environment',
#   'bring',
#   'important',
#   'aspect',
#   'imagination',
#   'underground',
#   'world',
#   'change',
#   'matter',
#   'endure',
#   'imprint',
#   'bury',
#   'ground',
#   'later',
#   'reappear',
#   'like',
#   'ton',
#   'ammunition',
#   'bury',
#   'second',
#   'world',
#   'war',
#   'mitholz',
#   'depot',
#   'bernese',
#   'oberland',
#   'cause',
#   'deadly',
#   'explosion',
#   'explode',
#   'explore',
#   'kind',
#   'depth',
#   'literary',
#   'work',
#   'story',
#   'swiss',
#   'cartographer',
#   'send',
#   'mission',
#   'define',
#   'europe',
#   's',
#   'eastern',
#   'border',
#   'cartographer',
#   'arrive',
#   'castle',
#   'boyar',
#   'near',
#   'ukraine',
#   'aim',
#   'study',
#   'collection',
#   'old',
#   'map',
#   'establish',
#   'exact',
#   'line',
#   'border',
#   'map',
#   'contradict',
#   'line',
#   'course',
#   'castle',
#   'slowly',
#   'sink',
#   'ground',
#   'theme',
#   'interest',
#   'link',
#   'branch',
#   'geographic',
#   'information',
#   'system',
#   'call',
#   'geodesy',
#   'regularly',
#   'recalculate',
#   'coordinate',
#   'series',
#   'point',
#   'earth',
#   'landmark',
#   'relatively',
#   'quickly',
#   'continental',
#   'drift',
#   'high',
#   'centimetre',
#   'year',
#   'kilometre',
#   'foundation',
#   'jericho',
#   'fascinate',
#   'fact',
#   'land',
#   'not',
#   'permanent',
#   'give',
#   'movement',
#   'tectonic',
#   'plate',
#   'border',
#   'historically',
#   'appear',
#   'geologically',
#   'follow',
#   'movement',
#   'earth',
#   's',
#   'surface',
#   'imply',
#   'fundamental',
#   'instability',
#   'reference',
#   'territory',
#   'theme',
#   'relate',
#   'movement',
#   'castle',
#   'sinking',
#   'point',
#   'protagonist',
#   'go',
#   'dig',
#   'cellar',
#   'discover',
#   'foundation',
#   'building',
#   'macerate',
#   'clay',
#   'confront',
#   'earth',
#   's',
#   'capacity',
#   'swallow',
#   'reality',
#   'build',
#   'fact',
#   'form',
#   'human',
#   'project',
#   'sooner',
#   'later',
#   'absorb',
#   'shapeless',
#   'mud',
#   'connect',
#   'imagery',
#   'underground',
#   'big',
#   'datum']]

# %% [raw]
# ## Using Gensim's phrases model, we can easily identify some MWEs in the corpus.
# ## This puts words like 'open' and 'science' into a bigram 'open_science'.

# %%
trained_phrases = models.phrases.Phrases(corpus) # train a phrase model
phraser = models.phrases.Phraser(trained_phrases) # initialise the trained phraser model
corpus_phrased = [phraser[text] for text in corpus] # apply phraser model to each text in corpus
# inspect the first text in the corpus after applying the phrase model
# corpus_phrased[3]

# %%
dictionary = corpora.Dictionary(corpus_phrased)
mapped_corpus = [dictionary.doc2bow(doc) for doc in corpus_phrased]
# inspect mapped_corpus
# corpus[1][0:10]

# %%
def print_topics_gensim(topic_model, total_topics=1, weight_threshold=0.0001, num_terms=None):
    """Adapted pretty print topic model results from Sakar (2016) Text Analytics With Python."""
    for index in range(total_topics):
        topic = topic_model.show_topic(index)
        topic = [(word, round(wt,4)) for word, wt in topic if abs(wt) >= weight_threshold]
        print('Topic #'+str(index+1))
        print(topic[:num_terms] if num_terms else topic)
        print()

def train_lda_model_gensim(corpus, total_topics=2):
    """Adapted pretty print topic model results from Sakar (2016) Text Analytics With Python."""
    dictionary = corpora.Dictionary(corpus)
    mapped_corpus = [dictionary.doc2bow(text) for text in corpus]
    tfidf = models.TfidfModel(mapped_corpus)
    corpus_tfidf = tfidf[mapped_corpus]
    lda = models.LdaModel(corpus_tfidf, id2word=dictionary, iterations=1000, num_topics=total_topics)
    return lda

# %%
def run_model_for_X_topics(X=2):
    lda_gensim = train_lda_model_gensim(corpus_phrased, total_topics=X)
    print_topics_gensim(topic_model=lda_gensim, total_topics=X, num_terms=10)

# %%
run_model_for_X_topics(10)
# Out:
# Topic #1
# [('selenium', 0.0011), ('disgust', 0.0008), ('ghernaouti', 0.0008), ('markwalder', 0.0007), ('robot', 0.0007), ('hartmann', 0.0007), ('sentence', 0.0007), ('public', 0.0007), ('criminal', 0.0006), ('justice_system', 0.0006)]
#
# Topic #2
# [('sign_language', 0.0011), ('memristor', 0.0009), ('caffeine', 0.0009), ('underground', 0.0008), ('be', 0.0007), ('chafer', 0.0007), ('energy', 0.0007), ('general_consent', 0.0007), ('subsoil', 0.0007), ('legislation', 0.0007)]
#
# Topic #3
# [('elephant', 0.0009), ('gravitational', 0.0008), ('cement', 0.0008), ('küffer', 0.0008), ('rickli', 0.0007), ('lösch', 0.0007), ('age', 0.0007), ('biodiversity', 0.0006), ('video_game', 0.0006), ('pelican', 0.0006)]
#
# Topic #4
# [('vayena', 0.001), ('patient', 0.001), ('papetti', 0.0008), ('war', 0.0008), ('mountain', 0.0007), ('medical', 0.0007), ('populist', 0.0007), ('soil', 0.0007), ('robot', 0.0007), ('datum', 0.0007)]
#
# Topic #5
# [('language', 0.0011), ('game', 0.0009), ('english', 0.0007), ('dyslexia', 0.0007), ('brain', 0.0007), ('oscillation', 0.0007), ('politic', 0.0006), ('un', 0.0006), ('drilling', 0.0005), ('teach', 0.0005)]
#
# Topic #6
# [('photon', 0.0009), ('aerogel', 0.0008), ('briel', 0.0008), ('satellite', 0.0008), ('koebel', 0.0008), ('story', 0.0007), ('reader', 0.0006), ('amygdala', 0.0006), ('collection', 0.0006), ('novel', 0.0006)]
#
# Topic #7
# [('finger', 0.0011), ('roska', 0.0011), ('dnn', 0.0011), ('wind', 0.0009), ('salt', 0.0006), ('algae', 0.0006), ('lake', 0.0006), ('pine', 0.0006), ('zebra', 0.0006), ('botond', 0.0005)]
#
# Topic #8
# [('felli', 0.0011), ('zebrafish', 0.0009), ('animal', 0.0007), ('measurement', 0.0007), ('affolter', 0.0006), ('organism', 0.0006), ('paramecia', 0.0006), ('nanotransporter', 0.0006), ('asylum', 0.0006), ('credibility', 0.0006)]
#
# Topic #9
# [('cell', 0.0011), ('indienne', 0.0009), ('image', 0.0009), ('video', 0.0008), ('retiree', 0.0008), ('self_experimentation', 0.0008), ('collection', 0.0008), ('briquette', 0.0007), ('bone', 0.0007), ('coal', 0.0007)]
#
# Topic #10
# [('child', 0.001), ('turkey', 0.0009), ('scholar', 0.0009), ('drug', 0.0008), ('partner', 0.0008), ('datum', 0.0008), ('software', 0.0008), ('wub', 0.0008), ('fat', 0.0007), ('pregnant_woman', 0.0006)]
